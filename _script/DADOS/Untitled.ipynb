# %%
# Importar arquivo csv e transformar em dataframe
import pandas as pd
import numpy as np
import re


speeds = pd.DataFrame(
    [
        ("bird", "Falconiformes", 389.0),
        ("bird", "Psittaciformes", 24.0),
        ("mammal", "Carnivora", '80A'),
        ("mammal", "Primates", np.nan),
        ("mammal", "Carnivora", 58),
    ],
    index=["falcon", "parrot", "lion", "monkey", "leopard"],
    columns=("class", "order", "max_speed"),
)

speeds
# Out:
# C:\Users\59186950010\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
#           class           order max_speed
# falcon     bird   Falconiformes     389.0
# parrot     bird  Psittaciformes      24.0
# lion     mammal       Carnivora       80A
# monkey   mammal        Primates       NaN
# leopard  mammal       Carnivora        58

# %%
grouped = speeds.groupby('class').mean()
print(grouped.head())

# %%
def ret_num_ui(num_ui):
    vlr = ''.join(filter(str.isdigit, str(num_ui)))
    if(vlr == ''):
        return np.NaN
    else:
        return vlr
    
speeds['max_speed']=speeds['max_speed'].apply(lambda x:ret_num_ui(x))
speeds

# %%
speeds['media'] = pd.to_numeric(speeds['max_speed'], errors='coerce')
speeds
